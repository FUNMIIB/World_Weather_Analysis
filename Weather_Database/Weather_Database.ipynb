# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7b3aa176c0f6f7cc08ca52d635ca14ce

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"] 
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mount isa
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | tautira
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto escondido
# Processing Record 10 of Set 1 | gat
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | linhares
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | port augusta
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | elat
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | moreira
# Processing Record 26 of Set 1 | uyuni
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | mahajanga
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | klyuchi
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | riverton
# Processing Record 39 of Set 1 | paragominas
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | ryotsu
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | haverfordwest
# Processing Record 44 of Set 1 | upata
# Processing Record 45 of Set 1 | saskylakh
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | hambantota
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | seleus
# Processing Record 1 of Set 2 | dunmore town
# Processing Record 2 of Set 2 | nishihara
# Processing Record 3 of Set 2 | tecoanapa
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | chingirlau
# Processing Record 6 of Set 2 | vila velha
# Processing Record 7 of Set 2 | bacungan
# Processing Record 8 of Set 2 | caramay
# Processing Record 9 of Set 2 | belyy yar
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | geraldton
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | altenburg
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | fortuna
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | bandarbeyla
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | malacacheta
# Processing Record 22 of Set 2 | karratha
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | rocha
# Processing Record 25 of Set 2 | belgrade
# Processing Record 26 of Set 2 | pilar
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | kuah
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 2 | leshukonskoye
# Processing Record 36 of Set 2 | grootfontein
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | araguaina
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | darhan
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 2 | dickinson
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | bandar
# Processing Record 47 of Set 2 | alyangula
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | kahului
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | providencia
# Processing Record 3 of Set 3 | aguimes
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | lorengau
# Processing Record 6 of Set 3 | aswan
# Processing Record 7 of Set 3 | olafsvik
# Processing Record 8 of Set 3 | sosnovo-ozerskoye
# Processing Record 9 of Set 3 | goma
# Processing Record 10 of Set 3 | grand gaube
# Processing Record 11 of Set 3 | khatanga
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | misratah
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | ketchikan
# Processing Record 16 of Set 3 | berlevag
# Processing Record 17 of Set 3 | piedras negras
# Processing Record 18 of Set 3 | parrita
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | soc trang
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | ekhabi
# Processing Record 23 of Set 3 | sorata
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | platteville
# Processing Record 26 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 27 of Set 3 | bathsheba
# Processing Record 28 of Set 3 | lata
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | gravdal
# Processing Record 31 of Set 3 | wilmington island
# Processing Record 32 of Set 3 | ambon
# Processing Record 33 of Set 3 | dongsheng
# Processing Record 34 of Set 3 | alofi
# Processing Record 35 of Set 3 | kirakira
# Processing Record 36 of Set 3 | ghanzi
# Processing Record 37 of Set 3 | guhagar
# Processing Record 38 of Set 3 | antofagasta
# Processing Record 39 of Set 3 | atherton
# Processing Record 40 of Set 3 | lagos
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | yar-sale
# Processing Record 43 of Set 3 | altay
# Processing Record 44 of Set 3 | rasskazovo
# Processing Record 45 of Set 3 | yaan
# Processing Record 46 of Set 3 | tchollire
# Processing Record 47 of Set 3 | springville
# Processing Record 48 of Set 3 | yefira
# City not found. Skipping...
# Processing Record 49 of Set 3 | mednogorskiy
# Processing Record 50 of Set 3 | flin flon
# Processing Record 1 of Set 4 | nordfjordeid
# Processing Record 2 of Set 4 | calvia
# Processing Record 3 of Set 4 | kokopo
# Processing Record 4 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 5 of Set 4 | huejuquilla el alto
# Processing Record 6 of Set 4 | beisfjord
# Processing Record 7 of Set 4 | santa maria
# Processing Record 8 of Set 4 | okato
# Processing Record 9 of Set 4 | north myrtle beach
# Processing Record 10 of Set 4 | riyadh
# Processing Record 11 of Set 4 | torbay
# Processing Record 12 of Set 4 | cidreira
# Processing Record 13 of Set 4 | hasaki
# Processing Record 14 of Set 4 | ambunti
# Processing Record 15 of Set 4 | vanimo
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | vicuna
# Processing Record 18 of Set 4 | miyako
# Processing Record 19 of Set 4 | mayo
# Processing Record 20 of Set 4 | omboue
# Processing Record 21 of Set 4 | sawtell
# Processing Record 22 of Set 4 | naze
# Processing Record 23 of Set 4 | gariaband
# Processing Record 24 of Set 4 | kaohsiung
# Processing Record 25 of Set 4 | ostrovnoy
# Processing Record 26 of Set 4 | whyalla
# Processing Record 27 of Set 4 | ambulu
# Processing Record 28 of Set 4 | bambous virieux
# Processing Record 29 of Set 4 | calama
# Processing Record 30 of Set 4 | cabra
# Processing Record 31 of Set 4 | bilibino
# Processing Record 32 of Set 4 | sebrovo
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | coolum beach
# Processing Record 35 of Set 4 | lebu
# Processing Record 36 of Set 4 | parabel
# Processing Record 37 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 4 | shimoda
# Processing Record 39 of Set 4 | santa cruz del norte
# Processing Record 40 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 4 | tikhvin
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | cayenne
# Processing Record 44 of Set 4 | port lincoln
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 4 | muros
# Processing Record 48 of Set 4 | divala
# Processing Record 49 of Set 4 | nuuk
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | alcains
# Processing Record 2 of Set 5 | yerbogachen
# Processing Record 3 of Set 5 | tiksi
# Processing Record 4 of Set 5 | rockland
# Processing Record 5 of Set 5 | margate
# Processing Record 6 of Set 5 | waipawa
# Processing Record 7 of Set 5 | batangafo
# Processing Record 8 of Set 5 | kolondieba
# Processing Record 9 of Set 5 | lasa
# Processing Record 10 of Set 5 | coahuayana
# Processing Record 11 of Set 5 | srednekolymsk
# Processing Record 12 of Set 5 | camargo
# Processing Record 13 of Set 5 | frutal
# Processing Record 14 of Set 5 | aykhal
# Processing Record 15 of Set 5 | alihe
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | moose factory
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | svetlaya
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 5 | belaya gora
# Processing Record 24 of Set 5 | ponta delgada
# Processing Record 25 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 26 of Set 5 | pacific grove
# Processing Record 27 of Set 5 | cedar city
# Processing Record 28 of Set 5 | rovnoye
# Processing Record 29 of Set 5 | tilichiki
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | rio gallegos
# Processing Record 32 of Set 5 | timbiras
# Processing Record 33 of Set 5 | peace river
# Processing Record 34 of Set 5 | husavik
# Processing Record 35 of Set 5 | gilgil
# City not found. Skipping...
# Processing Record 36 of Set 5 | longyearbyen
# Processing Record 37 of Set 5 | olhao
# Processing Record 38 of Set 5 | rosa zarate
# Processing Record 39 of Set 5 | am timan
# Processing Record 40 of Set 5 | chapais
# Processing Record 41 of Set 5 | rudbar
# Processing Record 42 of Set 5 | susehri
# Processing Record 43 of Set 5 | corinto
# Processing Record 44 of Set 5 | uni
# Processing Record 45 of Set 5 | ahipara
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | xichang
# Processing Record 48 of Set 5 | kimbe
# Processing Record 49 of Set 5 | cherskiy
# Processing Record 50 of Set 5 | poddorye
# Processing Record 1 of Set 6 | beloha
# Processing Record 2 of Set 6 | bani walid
# Processing Record 3 of Set 6 | arica
# Processing Record 4 of Set 6 | iqaluit
# Processing Record 5 of Set 6 | angoche
# Processing Record 6 of Set 6 | vanavara
# Processing Record 7 of Set 6 | funtua
# Processing Record 8 of Set 6 | vagay
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | dukat
# Processing Record 11 of Set 6 | saint-augustin
# Processing Record 12 of Set 6 | verdalsora
# City not found. Skipping...
# Processing Record 13 of Set 6 | linfen
# Processing Record 14 of Set 6 | port elizabeth
# Processing Record 15 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 16 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 6 | charters towers
# Processing Record 18 of Set 6 | jinchang
# Processing Record 19 of Set 6 | morden
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | marabba
# Processing Record 22 of Set 6 | buala
# Processing Record 23 of Set 6 | prince rupert
# Processing Record 24 of Set 6 | provideniya
# Processing Record 25 of Set 6 | barbastro
# Processing Record 26 of Set 6 | chokurdakh
# Processing Record 27 of Set 6 | bagrami
# Processing Record 28 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 6 | severnoye
# Processing Record 30 of Set 6 | vila franca do campo
# Processing Record 31 of Set 6 | filingue
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | avera
# Processing Record 34 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 6 | saint-francois
# Processing Record 37 of Set 6 | oistins
# Processing Record 38 of Set 6 | purificacion
# Processing Record 39 of Set 6 | independence
# Processing Record 40 of Set 6 | samarinda
# Processing Record 41 of Set 6 | portland
# Processing Record 42 of Set 6 | bam
# Processing Record 43 of Set 6 | peoria
# Processing Record 44 of Set 6 | cootamundra
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 6 | tabuk
# Processing Record 48 of Set 6 | port moresby
# Processing Record 49 of Set 6 | saint-pierre
# Processing Record 50 of Set 6 | myre
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | talnakh
# Processing Record 3 of Set 7 | balabac
# Processing Record 4 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 7 | lyman
# Processing Record 6 of Set 7 | sainte-thecle
# Processing Record 7 of Set 7 | honavar
# Processing Record 8 of Set 7 | caravelas
# Processing Record 9 of Set 7 | auki
# Processing Record 10 of Set 7 | maceio
# Processing Record 11 of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 12 of Set 7 | khakhea
# Processing Record 13 of Set 7 | coquimbo
# Processing Record 14 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 7 | auray
# Processing Record 16 of Set 7 | borsodnadasd
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | jaciara
# Processing Record 19 of Set 7 | sola
# Processing Record 20 of Set 7 | augusto correa
# Processing Record 21 of Set 7 | palmer
# Processing Record 22 of Set 7 | aykino
# Processing Record 23 of Set 7 | huancabamba
# Processing Record 24 of Set 7 | pokhara
# Processing Record 25 of Set 7 | betare oya
# Processing Record 26 of Set 7 | naron
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | katobu
# Processing Record 29 of Set 7 | warwick
# Processing Record 30 of Set 7 | bereda
# Processing Record 31 of Set 7 | trapani
# Processing Record 32 of Set 7 | tuatapere
# Processing Record 33 of Set 7 | uspenskaya
# Processing Record 34 of Set 7 | todos santos
# Processing Record 35 of Set 7 | yekaterinovka
# Processing Record 36 of Set 7 | gazojak
# Processing Record 37 of Set 7 | tevaitoa
# Processing Record 38 of Set 7 | ginir
# Processing Record 39 of Set 7 | tarabuco
# Processing Record 40 of Set 7 | nokha
# Processing Record 41 of Set 7 | mae sai
# Processing Record 42 of Set 7 | de-kastri
# Processing Record 43 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 7 | la romana
# Processing Record 45 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 7 | alexandria
# Processing Record 47 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 48 of Set 7 | baghdad
# Processing Record 49 of Set 7 | champerico
# Processing Record 50 of Set 7 | lakatoro
# Processing Record 1 of Set 8 | barabai
# Processing Record 2 of Set 8 | dingle
# Processing Record 3 of Set 8 | bairiki
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | kambove
# Processing Record 6 of Set 8 | vao
# Processing Record 7 of Set 8 | ixtapa
# Processing Record 8 of Set 8 | agadir
# Processing Record 9 of Set 8 | santa rosa
# Processing Record 10 of Set 8 | bethel
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | saint anthony
# Processing Record 13 of Set 8 | tacoronte
# Processing Record 14 of Set 8 | la libertad
# Processing Record 15 of Set 8 | puerto quijarro
# Processing Record 16 of Set 8 | maridi
# Processing Record 17 of Set 8 | mitsamiouli
# Processing Record 18 of Set 8 | teknaf
# Processing Record 19 of Set 8 | ylivieska
# Processing Record 20 of Set 8 | sinnamary
# Processing Record 21 of Set 8 | jalu
# Processing Record 22 of Set 8 | flinders
# Processing Record 23 of Set 8 | touros
# Processing Record 24 of Set 8 | half moon bay
# Processing Record 25 of Set 8 | grindavik
# Processing Record 26 of Set 8 | ulladulla
# Processing Record 27 of Set 8 | te anau
# Processing Record 28 of Set 8 | staryy oskol
# Processing Record 29 of Set 8 | adrar
# Processing Record 30 of Set 8 | monte alegre de sergipe
# Processing Record 31 of Set 8 | plettenberg bay
# Processing Record 32 of Set 8 | aksu
# Processing Record 33 of Set 8 | bud
# Processing Record 34 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | coihaique
# Processing Record 36 of Set 8 | tres arroyos
# Processing Record 37 of Set 8 | oriximina
# Processing Record 38 of Set 8 | keti bandar
# Processing Record 39 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 8 | airai
# Processing Record 41 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 8 | collie
# Processing Record 43 of Set 8 | sur
# Processing Record 44 of Set 8 | catamarca
# Processing Record 45 of Set 8 | pitsunda
# Processing Record 46 of Set 8 | zhanaozen
# Processing Record 47 of Set 8 | tomatlan
# Processing Record 48 of Set 8 | roald
# Processing Record 49 of Set 8 | isangel
# Processing Record 50 of Set 8 | nyurba
# Processing Record 1 of Set 9 | trincomalee
# Processing Record 2 of Set 9 | kapoeta
# Processing Record 3 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 9 | crimmitschau
# Processing Record 5 of Set 9 | jalingo
# Processing Record 6 of Set 9 | kununurra
# Processing Record 7 of Set 9 | russell
# Processing Record 8 of Set 9 | marawi
# Processing Record 9 of Set 9 | springfield
# Processing Record 10 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 9 | chumikan
# Processing Record 12 of Set 9 | san vicente
# Processing Record 13 of Set 9 | esperance
# Processing Record 14 of Set 9 | carutapera
# Processing Record 15 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 9 | port macquarie
# Processing Record 17 of Set 9 | constitucion
# Processing Record 18 of Set 9 | tatarastii de sus
# City not found. Skipping...
# Processing Record 19 of Set 9 | orange cove
# Processing Record 20 of Set 9 | chicama
# Processing Record 21 of Set 9 | vagur
# Processing Record 22 of Set 9 | faya
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 9 | kijang
# Processing Record 26 of Set 9 | souillac
# Processing Record 27 of Set 9 | tongzi
# Processing Record 28 of Set 9 | marsabit
# Processing Record 29 of Set 9 | kulhudhuffushi
# Processing Record 30 of Set 9 | matara
# Processing Record 31 of Set 9 | kangaatsiaq
# Processing Record 32 of Set 9 | port-gentil
# Processing Record 33 of Set 9 | san andres
# Processing Record 34 of Set 9 | tura
# Processing Record 35 of Set 9 | ayagoz
# Processing Record 36 of Set 9 | newcastle
# Processing Record 37 of Set 9 | phuthaditjhaba
# Processing Record 38 of Set 9 | midland
# Processing Record 39 of Set 9 | barra do garcas
# Processing Record 40 of Set 9 | port blair
# Processing Record 41 of Set 9 | lodja
# Processing Record 42 of Set 9 | hobyo
# Processing Record 43 of Set 9 | mount gambier
# Processing Record 44 of Set 9 | bikaner
# Processing Record 45 of Set 9 | hofn
# Processing Record 46 of Set 9 | kropotkin
# Processing Record 47 of Set 9 | necochea
# Processing Record 48 of Set 9 | svetlogorsk
# Processing Record 49 of Set 9 | broken hill
# Processing Record 50 of Set 9 | pabna
# Processing Record 1 of Set 10 | sao joao da barra
# Processing Record 2 of Set 10 | graz
# Processing Record 3 of Set 10 | aklavik
# Processing Record 4 of Set 10 | sept-iles
# Processing Record 5 of Set 10 | alice springs
# Processing Record 6 of Set 10 | rawson
# Processing Record 7 of Set 10 | imbituba
# Processing Record 8 of Set 10 | rafaela
# Processing Record 9 of Set 10 | lompoc
# Processing Record 10 of Set 10 | asau
# Processing Record 11 of Set 10 | dauphin
# Processing Record 12 of Set 10 | berbera
# Processing Record 13 of Set 10 | shellbrook
# Processing Record 14 of Set 10 | iglesias
# Processing Record 15 of Set 10 | sikonge
# Processing Record 16 of Set 10 | nuevo progreso
# Processing Record 17 of Set 10 | laguna
# Processing Record 18 of Set 10 | kiunga
# Processing Record 19 of Set 10 | sholapur
# Processing Record 20 of Set 10 | brainerd
# Processing Record 21 of Set 10 | soyo
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | althofen
# Processing Record 24 of Set 10 | suratgarh
# Processing Record 25 of Set 10 | avesta
# Processing Record 26 of Set 10 | biak
# Processing Record 27 of Set 10 | tuskegee
# Processing Record 28 of Set 10 | takoradi
# Processing Record 29 of Set 10 | mikhaylovka
# Processing Record 30 of Set 10 | lensk
# Processing Record 31 of Set 10 | balti
# Processing Record 32 of Set 10 | miranda
# Processing Record 33 of Set 10 | coldingham
# Processing Record 34 of Set 10 | nakuru
# Processing Record 35 of Set 10 | brigantine
# Processing Record 36 of Set 10 | bundaberg
# Processing Record 37 of Set 10 | yatou
# Processing Record 38 of Set 10 | pochutla
# Processing Record 39 of Set 10 | huai thalaeng
# Processing Record 40 of Set 10 | requena
# Processing Record 41 of Set 10 | udachnyy
# Processing Record 42 of Set 10 | kaeo
# Processing Record 43 of Set 10 | ancud
# Processing Record 44 of Set 10 | yantal
# Processing Record 45 of Set 10 | les cayes
# Processing Record 46 of Set 10 | tateyama
# Processing Record 47 of Set 10 | kavieng
# Processing Record 48 of Set 10 | shahr-e babak
# Processing Record 49 of Set 10 | beira
# Processing Record 50 of Set 10 | rio grande
# Processing Record 1 of Set 11 | garm
# City not found. Skipping...
# Processing Record 2 of Set 11 | lashio
# Processing Record 3 of Set 11 | ouadda
# Processing Record 4 of Set 11 | meulaboh
# Processing Record 5 of Set 11 | agnibilekrou
# Processing Record 6 of Set 11 | brewster
# Processing Record 7 of Set 11 | ahuimanu
# Processing Record 8 of Set 11 | havre-saint-pierre
# Processing Record 9 of Set 11 | wa
# City not found. Skipping...
# Processing Record 10 of Set 11 | san angelo
# Processing Record 11 of Set 11 | nome
# Processing Record 12 of Set 11 | rajo khanani
# Processing Record 13 of Set 11 | tzucacab
# Processing Record 14 of Set 11 | shwebo
# Processing Record 15 of Set 11 | sechura
# Processing Record 16 of Set 11 | kushima
# Processing Record 17 of Set 11 | palana
# Processing Record 18 of Set 11 | sohag
# Processing Record 19 of Set 11 | awjilah
# Processing Record 20 of Set 11 | richards bay
# Processing Record 21 of Set 11 | pangnirtung
# Processing Record 22 of Set 11 | savannakhet
# Processing Record 23 of Set 11 | samarai
# Processing Record 24 of Set 11 | maniitsoq
# Processing Record 25 of Set 11 | dali
# Processing Record 26 of Set 11 | komsomolskiy
# Processing Record 27 of Set 11 | la ronge
# Processing Record 28 of Set 11 | fredericksburg
# Processing Record 29 of Set 11 | cuamba
# Processing Record 30 of Set 11 | grande prairie
# Processing Record 31 of Set 11 | jales
# Processing Record 32 of Set 11 | hesla
# Processing Record 33 of Set 11 | taoudenni
# Processing Record 34 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 35 of Set 11 | urubicha
# Processing Record 36 of Set 11 | batemans bay
# Processing Record 37 of Set 11 | gualeguay
# Processing Record 38 of Set 11 | camacha
# Processing Record 39 of Set 11 | leningradskiy
# Processing Record 40 of Set 11 | saint-louis
# Processing Record 41 of Set 11 | libenge
# Processing Record 42 of Set 11 | shambu
# Processing Record 43 of Set 11 | galveston
# Processing Record 44 of Set 11 | khvorostyanka
# Processing Record 45 of Set 11 | asasa
# Processing Record 46 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 11 | kenai
# Processing Record 48 of Set 11 | baykit
# Processing Record 49 of Set 11 | guayaquil
# Processing Record 50 of Set 11 | frontera
# Processing Record 1 of Set 12 | reserva
# Processing Record 2 of Set 12 | san cristobal
# Processing Record 3 of Set 12 | hebertville
# City not found. Skipping...
# Processing Record 4 of Set 12 | magistralnyy
# Processing Record 5 of Set 12 | nisia floresta
# Processing Record 6 of Set 12 | vastervik
# City not found. Skipping...
# Processing Record 7 of Set 12 | amuntai
# Processing Record 8 of Set 12 | rusape
# Processing Record 9 of Set 12 | vestmannaeyjar
# Processing Record 10 of Set 12 | beri
# Processing Record 11 of Set 12 | aksarka
# Processing Record 12 of Set 12 | zaysan
# Processing Record 13 of Set 12 | san quintin
# Processing Record 14 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 12 | okhotsk
# Processing Record 16 of Set 12 | praya
# Processing Record 17 of Set 12 | susa
# Processing Record 18 of Set 12 | jijiga
# Processing Record 19 of Set 12 | port-cartier
# Processing Record 20 of Set 12 | fresno
# Processing Record 21 of Set 12 | hualmay
# Processing Record 22 of Set 12 | lazo
# Processing Record 23 of Set 12 | bougouni
# Processing Record 24 of Set 12 | berea
# Processing Record 25 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 12 | mandera
# Processing Record 27 of Set 12 | vitim
# Processing Record 28 of Set 12 | mogadishu
# Processing Record 29 of Set 12 | pyaozerskiy
# Processing Record 30 of Set 12 | loucna nad desnou
# Processing Record 31 of Set 12 | puerto padre
# Processing Record 32 of Set 12 | chegdomyn
# Processing Record 33 of Set 12 | mareeba
# Processing Record 34 of Set 12 | forestville
# Processing Record 35 of Set 12 | lima
# Processing Record 36 of Set 12 | manzhouli
# Processing Record 37 of Set 12 | inirida
# Processing Record 38 of Set 12 | severo-yeniseyskiy
# Processing Record 39 of Set 12 | fukue
# Processing Record 40 of Set 12 | fort nelson
# Processing Record 41 of Set 12 | bayburt
# Processing Record 42 of Set 12 | medicine hat
# Processing Record 43 of Set 12 | victor harbor
# Processing Record 44 of Set 12 | chandbali
# Processing Record 45 of Set 12 | caracoli
# Processing Record 46 of Set 12 | thinadhoo
# Processing Record 47 of Set 12 | alice town
# Processing Record 48 of Set 12 | lipari
# Processing Record 49 of Set 12 | kyaikkami
# Processing Record 50 of Set 12 | looc
# Processing Record 1 of Set 13 | abu dhabi
# Processing Record 2 of Set 13 | shadrinsk
# Processing Record 3 of Set 13 | denpasar
# Processing Record 4 of Set 13 | kalispell
# Processing Record 5 of Set 13 | monte patria
# Processing Record 6 of Set 13 | ternate
# Processing Record 7 of Set 13 | springbok
# Processing Record 8 of Set 13 | bemidji
# Processing Record 9 of Set 13 | paramonga
# Processing Record 10 of Set 13 | capitan bado
# Processing Record 11 of Set 13 | mehran
# Processing Record 12 of Set 13 | kourou
# Processing Record 13 of Set 13 | deshna
# City not found. Skipping...
# Processing Record 14 of Set 13 | morondava
# Processing Record 15 of Set 13 | camocim
# Processing Record 16 of Set 13 | obo
# Processing Record 17 of Set 13 | cusuna
# Processing Record 18 of Set 13 | ustupo
# Processing Record 19 of Set 13 | tshikapa
# Processing Record 20 of Set 13 | tarauaca
# Processing Record 21 of Set 13 | vyborg
# Processing Record 22 of Set 13 | shelburne
# Processing Record 23 of Set 13 | nikita
# Processing Record 24 of Set 13 | leh
# Processing Record 25 of Set 13 | tome-acu
# City not found. Skipping...
# Processing Record 26 of Set 13 | birao
# Processing Record 27 of Set 13 | vizinga
# Processing Record 28 of Set 13 | xuddur
# Processing Record 29 of Set 13 | mayya
# Processing Record 30 of Set 13 | dawlatabad
# Processing Record 31 of Set 13 | volokolamsk
# Processing Record 32 of Set 13 | nilakkottai
# Processing Record 33 of Set 13 | van
# Processing Record 34 of Set 13 | iberia
# Processing Record 35 of Set 13 | hami
# Processing Record 36 of Set 13 | honiara
# Processing Record 37 of Set 13 | maldonado
# Processing Record 38 of Set 13 | yermakovskoye
# Processing Record 39 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 13 | henties bay
# Processing Record 41 of Set 13 | kathu
# Processing Record 42 of Set 13 | shupiyan
# Processing Record 43 of Set 13 | khovu-aksy
# Processing Record 44 of Set 13 | glenwood springs
# Processing Record 45 of Set 13 | male
# Processing Record 46 of Set 13 | severodvinsk
# Processing Record 47 of Set 13 | storm lake
# Processing Record 48 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 49 of Set 13 | ust-kan
# Processing Record 50 of Set 13 | mana
# Processing Record 1 of Set 14 | manaira
# Processing Record 2 of Set 14 | tual
# Processing Record 3 of Set 14 | bethalto
# Processing Record 4 of Set 14 | sorong
# Processing Record 5 of Set 14 | burica
# City not found. Skipping...
# Processing Record 6 of Set 14 | cap-aux-meules
# Processing Record 7 of Set 14 | axim
# Processing Record 8 of Set 14 | cairns
# Processing Record 9 of Set 14 | progreso
# Processing Record 10 of Set 14 | banda aceh
# Processing Record 11 of Set 14 | dallas
# Processing Record 12 of Set 14 | vostok
# Processing Record 13 of Set 14 | forio
# Processing Record 14 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 14 | bara
# Processing Record 16 of Set 14 | oyama
# Processing Record 17 of Set 14 | alekseyevsk
# Processing Record 18 of Set 14 | mezen
# Processing Record 19 of Set 14 | mirnyy
# Processing Record 20 of Set 14 | weihai
# Processing Record 21 of Set 14 | okmulgee
# Processing Record 22 of Set 14 | kindu
# Processing Record 23 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 24 of Set 14 | igrim
# Processing Record 25 of Set 14 | marsh harbour
# Processing Record 26 of Set 14 | manoel urbano
# Processing Record 27 of Set 14 | varhaug
# Processing Record 28 of Set 14 | maxixe
# Processing Record 29 of Set 14 | the valley
# Processing Record 30 of Set 14 | quatre cocos
# Processing Record 31 of Set 14 | kailua
# Processing Record 32 of Set 14 | guaruja
# Processing Record 33 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 14 | makakilo city
# Processing Record 35 of Set 14 | tuma
# Processing Record 36 of Set 14 | taltal
# Processing Record 37 of Set 14 | traunreut
# Processing Record 38 of Set 14 | verkh-neyvinskiy
# Processing Record 39 of Set 14 | magura
# Processing Record 40 of Set 14 | ankazoabo
# Processing Record 41 of Set 14 | san miguelito
# Processing Record 42 of Set 14 | mazagao
# Processing Record 43 of Set 14 | inuvik
# Processing Record 44 of Set 14 | ust-ilimsk
# Processing Record 45 of Set 14 | santa cruz de la palma
# Processing Record 46 of Set 14 | santa marta
# Processing Record 47 of Set 14 | teterow
# Processing Record 48 of Set 14 | le port
# Processing Record 49 of Set 14 | dunedin
# Processing Record 50 of Set 14 | pathein
# Processing Record 1 of Set 15 | sao filipe
# Processing Record 2 of Set 15 | manzanillo
# Processing Record 3 of Set 15 | yeniseysk
# Processing Record 4 of Set 15 | buraydah
# Processing Record 5 of Set 15 | ambanja
# Processing Record 6 of Set 15 | itacare
# Processing Record 7 of Set 15 | gamba
# Processing Record 8 of Set 15 | wuwei
# Processing Record 9 of Set 15 | nizhneudinsk
# Processing Record 10 of Set 15 | tessalit
# Processing Record 11 of Set 15 | beziers
# Processing Record 12 of Set 15 | iwanai
# Processing Record 13 of Set 15 | bonfim
# Processing Record 14 of Set 15 | tigil
# Processing Record 15 of Set 15 | byron bay
# Processing Record 16 of Set 15 | carroll
# Processing Record 17 of Set 15 | erzurum
# Processing Record 18 of Set 15 | yulara
# Processing Record 19 of Set 15 | san carlos de bariloche
# Processing Record 20 of Set 15 | voyvozh
# Processing Record 21 of Set 15 | kudahuvadhoo
# Processing Record 22 of Set 15 | williams lake
# Processing Record 23 of Set 15 | ambilobe
# Processing Record 24 of Set 15 | vilyuysk
# Processing Record 25 of Set 15 | ilave
# Processing Record 26 of Set 15 | cururupu
# Processing Record 27 of Set 15 | teya
# Processing Record 28 of Set 15 | deputatskiy
# Processing Record 29 of Set 15 | bikin
# Processing Record 30 of Set 15 | bac lieu
# Processing Record 31 of Set 15 | sabang
# Processing Record 32 of Set 15 | rurrenabaque
# Processing Record 33 of Set 15 | hamilton
# Processing Record 34 of Set 15 | jacutinga
# Processing Record 35 of Set 15 | porto novo
# Processing Record 36 of Set 15 | hanzhong
# Processing Record 37 of Set 15 | mapiripan
# Processing Record 38 of Set 15 | moree
# Processing Record 39 of Set 15 | tapejara
# Processing Record 40 of Set 15 | ushtobe
# Processing Record 41 of Set 15 | broome
# Processing Record 42 of Set 15 | san pedro
# Processing Record 43 of Set 15 | foam lake
# Processing Record 44 of Set 15 | natal
# Processing Record 45 of Set 15 | road town
# Processing Record 46 of Set 15 | wagar
# Processing Record 47 of Set 15 | thunder bay
# Processing Record 48 of Set 15 | ridgecrest
# Processing Record 49 of Set 15 | jesup
# Processing Record 50 of Set 15 | linares
# Processing Record 1 of Set 16 | nizwa
# Processing Record 2 of Set 16 | westport
# Processing Record 3 of Set 16 | hay river
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mount Isa      AU -20.7333  139.5000     76.77        41           9
# 1       Butaritari      KI   3.0707  172.7902     80.62        80          39
# 2    Mar Del Plata      AR -38.0023  -57.5575     68.88        67          95
# 3          Tautira      PF -17.7333 -149.1500     84.22        69          18
# 4            Kapaa      US  22.0752 -159.3190     80.58        74          75
# ..             ...     ...      ...       ...       ...       ...         ...
# 693          Jesup      US  31.6074  -81.8854     75.22        53           1
# 694        Linares      CL -35.8500  -71.6000     91.74        11           2
# 695          Nizwa      OM  22.9333   57.5333     71.35        35          56
# 696       Westport      US  41.1415  -73.3579     54.99        64           1
# 697      Hay River      CA  60.8156 -115.7999      3.18        78          75
#
#      Wind Speed Current Description
# 0          8.05           clear sky
# 1          8.32    scattered clouds
# 2         11.99     overcast clouds
# 3          6.33          few clouds
# 4          1.99       broken clouds
# ..          ...                 ...
# 693        0.00           clear sky
# 694        9.17           clear sky
# 695        5.35       broken clouds
# 696        1.01           clear sky
# 697        5.75       broken clouds
#
# [698 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
